# %%
import numpy as np 
import pandas as pd 
from tqdm import tqdm
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from PIL import Image
from keras.utils.vis_utils import plot_model
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
model = Sequential()
model.add(MaxPooling2D(pool_size=2,input_shape=(320, 240, 3)))
model.add(Conv2D(3, kernel_size=(5,5), activation='relu',padding = 'Same'))
model.add(Conv2D(16,kernel_size=(5,5),activation='relu',padding = 'Same'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.15))

model.add(Conv2D(32,kernel_size=(5,5),activation='relu',padding = 'Same'))
model.add(Conv2D(32,kernel_size=(5,5),activation='relu',padding = 'Same'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.15))

model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# max_pooling2d_15 (MaxPooling (None, 160, 120, 3)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 160, 120, 3)       228
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 160, 120, 16)      1216
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 80, 60, 16)        0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 80, 60, 16)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 80, 60, 32)        12832
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 80, 60, 32)        25632
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 40, 30, 32)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 40, 30, 32)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 38400)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               9830656
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 9,870,821
# Trainable params: 9,870,821
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

image_size = 224
batch_size = 32

train_datagen = ImageDataGenerator(rescale=1./255., validation_split=0.20)

train_generator = train_datagen.flow_from_directory(directory ='../audio_data/juyeon/train_image',
                                                    subset = 'training',   
                                                    batch_size = batch_size,
                                                    seed = 0,
                                                    shuffle = True,
                                                    class_mode = 'binary',
                                                    target_size = (320,240))

valid_generator = train_datagen.flow_from_directory(directory = '../audio_data/juyeon/train_image',
                                                    subset = 'validation',
                                                    batch_size = batch_size,
                                                    seed = 0,
                                                    shuffle = True,
                                                    class_mode = 'binary',
                                                    target_size = (320,240))
# Out:
# Found 4068 images belonging to 2 classes.
# Found 1016 images belonging to 2 classes.

# %%
os.listdir('../audio_data/train_Mel')

# %%
os.rmdir('../audio_data/train_Mel/.ipynb_checkpoints')

# %%
for i in tqdm(range(train_generator.n)):
    x, y = train_generator.next()
#     print(x.shape, i)
    print(x)

# %%
for i in tqdm(range(valid_generator.n)):
    x, y = valid_generator.next()
#     print(x.shape, i)

# %%
train_generator.filepaths[3804]

# %%
train_generator.filenames[3818]

# %%
import os
os.path.isfile('../audio_data/juyeon/train_image/1/97wn.jpg')
os.remove('../audio_data/juyeon/train_image/1/97wn.jpg')

# %%
train_generator.class_indices

# %%
# fig_generator
from keras.callbacks import ModelCheckpoint, EarlyStopping

checkpoint_path = '../superjuyeon/check.h5'

cp = ModelCheckpoint(filepath=checkpoint_path,
                                save_weights_only=True,
                                save_best_only=True,
                                monitor='val_accuracy',
                                verbose=1)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                                   patience=5, 
                                   min_lr=1e-8)

es = EarlyStopping(patience=50, verbose=1)
history = model.fit_generator(
    train_generator,
    steps_per_epoch=train_generator.n//batch_size,
    epochs=200,
    validation_data=valid_generator,
    validation_steps=valid_generator.n//batch_size,
    callbacks=[es,cp,reduceLROnPlat]
)
model.summary()
# Out:
# Epoch 1/200
# 127/127 [==============================] - ETA: 0s - loss: 0.5544 - accuracy: 0.7168
# Epoch 00001: val_accuracy improved from -inf to 0.73185, saving model to ../superjuyeon/check.h5
# 127/127 [==============================] - 14s 110ms/step - loss: 0.5544 - accuracy: 0.7168 - val_loss: 0.6102 - val_accuracy: 0.7319
# Epoch 2/200
# 127/127 [==============================] - ETA: 0s - loss: 0.4579 - accuracy: 0.7864
# Epoch 00002: val_accuracy did not improve from 0.73185
# 127/127 [==============================] - 13s 104ms/step - loss: 0.4579 - accuracy: 0.7864 - val_loss: 0.5969 - val_accuracy: 0.7248
# Epoch 3/200
# 127/127 [==============================] - ETA: 0s - loss: 0.3577 - accuracy: 0.8389
# Epoch 00003: val_accuracy improved from 0.73185 to 0.77218, saving model to ../superjuyeon/check.h5
# 127/127 [==============================] - 14s 113ms/step - loss: 0.3577 - accuracy: 0.8389 - val_loss: 0.6597 - val_accuracy: 0.7722
# Epoch 4/200
# 127/127 [==============================] - ETA: 0s - loss: 0.2474 - accuracy: 0.8964
# Epoch 00004: val_accuracy did not improve from 0.77218
# 127/127 [==============================] - 15s 118ms/step - loss: 0.2474 - accuracy: 0.8964 - val_loss: 0.9546 - val_accuracy: 0.7671
# Epoch 5/200
# 127/127 [==============================] - ETA: 0s - loss: 0.1552 - accuracy: 0.9395
# Epoch 00005: val_accuracy did not improve from 0.77218
# 127/127 [==============================] - 13s 105ms/step - loss: 0.1552 - accuracy: 0.9395 - val_loss: 1.3534 - val_accuracy: 0.7520
# Epoch 6/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9646
# Epoch 00006: val_accuracy improved from 0.77218 to 0.78831, saving model to ../superjuyeon/check.h5
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0928 - accuracy: 0.9646 - val_loss: 1.4911 - val_accuracy: 0.7883
# Epoch 7/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9765
# Epoch 00007: val_accuracy improved from 0.78831 to 0.79032, saving model to ../superjuyeon/check.h5
# 127/127 [==============================] - 15s 114ms/step - loss: 0.0674 - accuracy: 0.9765 - val_loss: 1.9006 - val_accuracy: 0.7903
# Epoch 8/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9893
# Epoch 00008: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0325 - accuracy: 0.9893 - val_loss: 2.2582 - val_accuracy: 0.7873
# Epoch 9/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9955
# Epoch 00009: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0147 - accuracy: 0.9955 - val_loss: 3.0975 - val_accuracy: 0.7661
# Epoch 10/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9953
# Epoch 00010: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0136 - accuracy: 0.9953 - val_loss: 2.8923 - val_accuracy: 0.7823
# Epoch 11/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9985
# Epoch 00011: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0073 - accuracy: 0.9985 - val_loss: 2.9423 - val_accuracy: 0.7883
# Epoch 12/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9988
# Epoch 00012: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 3.3661 - val_accuracy: 0.7782
# Epoch 13/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9998
# Epoch 00013: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 3.4967 - val_accuracy: 0.7863
# Epoch 14/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9985
# Epoch 00014: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 3.9208 - val_accuracy: 0.7772
# Epoch 15/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9998
# Epoch 00015: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 3.5379 - val_accuracy: 0.7833
# Epoch 16/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9983
# Epoch 00016: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 3.8737 - val_accuracy: 0.7782
# Epoch 17/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9993
# Epoch 00017: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 104ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 3.9677 - val_accuracy: 0.7812
# Epoch 18/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9993
# Epoch 00018: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 3.6772 - val_accuracy: 0.7792
# Epoch 19/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995
# Epoch 00019: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 3.4969 - val_accuracy: 0.7823
# Epoch 20/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 00020: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 104ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 3.8483 - val_accuracy: 0.7782
# Epoch 21/200
# 127/127 [==============================] - ETA: 0s - loss: 9.9173e-04 - accuracy: 1.0000
# Epoch 00021: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 103ms/step - loss: 9.9173e-04 - accuracy: 1.0000 - val_loss: 3.8909 - val_accuracy: 0.7903
# Epoch 22/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9995
# Epoch 00022: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 15s 114ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 4.2243 - val_accuracy: 0.7782
# Epoch 23/200
# 127/127 [==============================] - ETA: 0s - loss: 9.2438e-04 - accuracy: 1.0000
# Epoch 00023: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 112ms/step - loss: 9.2438e-04 - accuracy: 1.0000 - val_loss: 4.2174 - val_accuracy: 0.7792
# Epoch 24/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9995
# Epoch 00024: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 104ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 4.1787 - val_accuracy: 0.7752
# Epoch 25/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 00025: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 4.2498 - val_accuracy: 0.7772
# Epoch 26/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9995
# Epoch 00026: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 112ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 4.3173 - val_accuracy: 0.7772
# Epoch 27/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 00027: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 108ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 4.1081 - val_accuracy: 0.7812
# Epoch 28/200
# 127/127 [==============================] - ETA: 0s - loss: 8.6155e-04 - accuracy: 1.0000
# Epoch 00028: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 103ms/step - loss: 8.6155e-04 - accuracy: 1.0000 - val_loss: 4.2139 - val_accuracy: 0.7792
# Epoch 29/200
# 127/127 [==============================] - ETA: 0s - loss: 9.6549e-04 - accuracy: 0.9998
# Epoch 00029: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 106ms/step - loss: 9.6549e-04 - accuracy: 0.9998 - val_loss: 4.0110 - val_accuracy: 0.7853
# Epoch 30/200
# 127/127 [==============================] - ETA: 0s - loss: 9.5310e-04 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 107ms/step - loss: 9.5310e-04 - accuracy: 1.0000 - val_loss: 4.4099 - val_accuracy: 0.7782
# Epoch 31/200
# 127/127 [==============================] - ETA: 0s - loss: 8.1381e-04 - accuracy: 1.0000
# Epoch 00031: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 104ms/step - loss: 8.1381e-04 - accuracy: 1.0000 - val_loss: 4.3619 - val_accuracy: 0.7833
# Epoch 32/200
# 127/127 [==============================] - ETA: 0s - loss: 8.3264e-04 - accuracy: 1.0000
# Epoch 00032: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 107ms/step - loss: 8.3264e-04 - accuracy: 1.0000 - val_loss: 4.3985 - val_accuracy: 0.7772
# Epoch 33/200
# 127/127 [==============================] - ETA: 0s - loss: 6.7235e-04 - accuracy: 1.0000
# Epoch 00033: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 112ms/step - loss: 6.7235e-04 - accuracy: 1.0000 - val_loss: 4.3380 - val_accuracy: 0.7833
# Epoch 34/200
# 127/127 [==============================] - ETA: 0s - loss: 9.9702e-04 - accuracy: 0.9998
# Epoch 00034: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 14s 113ms/step - loss: 9.9702e-04 - accuracy: 0.9998 - val_loss: 4.3018 - val_accuracy: 0.7853
# Epoch 35/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998
# Epoch 00035: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 4.2784 - val_accuracy: 0.7812
# Epoch 36/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998
# Epoch 00036: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 4.1951 - val_accuracy: 0.7853
# Epoch 37/200
# 127/127 [==============================] - ETA: 0s - loss: 8.5553e-04 - accuracy: 0.9998
# Epoch 00037: val_accuracy did not improve from 0.79032
# 127/127 [==============================] - 13s 105ms/step - loss: 8.5553e-04 - accuracy: 0.9998 - val_loss: 4.1842 - val_accuracy: 0.7893
# Epoch 38/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 00038: val_accuracy improved from 0.79032 to 0.79133, saving model to ../superjuyeon/check.h5
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 4.0771 - val_accuracy: 0.7913
# Epoch 39/200
# 127/127 [==============================] - ETA: 0s - loss: 7.4452e-04 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 13s 105ms/step - loss: 7.4452e-04 - accuracy: 1.0000 - val_loss: 4.0824 - val_accuracy: 0.7893
# Epoch 40/200
# 127/127 [==============================] - ETA: 0s - loss: 4.9460e-04 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 13s 106ms/step - loss: 4.9460e-04 - accuracy: 1.0000 - val_loss: 4.1411 - val_accuracy: 0.7873
# Epoch 41/200
# 127/127 [==============================] - ETA: 0s - loss: 4.4002e-04 - accuracy: 1.0000
# Epoch 00041: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 13s 106ms/step - loss: 4.4002e-04 - accuracy: 1.0000 - val_loss: 4.1875 - val_accuracy: 0.7863
# Epoch 42/200
# 127/127 [==============================] - ETA: 0s - loss: 8.3803e-04 - accuracy: 0.9998
# Epoch 00042: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 14s 111ms/step - loss: 8.3803e-04 - accuracy: 0.9998 - val_loss: 4.2415 - val_accuracy: 0.7863
# Epoch 43/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9995
# Epoch 00043: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 4.1861 - val_accuracy: 0.7863
# Epoch 44/200
# 127/127 [==============================] - ETA: 0s - loss: 6.9083e-04 - accuracy: 0.9998
# Epoch 00044: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 13s 104ms/step - loss: 6.9083e-04 - accuracy: 0.9998 - val_loss: 4.1867 - val_accuracy: 0.7823
# Epoch 45/200
# 127/127 [==============================] - ETA: 0s - loss: 6.5057e-04 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 14s 109ms/step - loss: 6.5057e-04 - accuracy: 1.0000 - val_loss: 4.2804 - val_accuracy: 0.7843
# Epoch 46/200
# 127/127 [==============================] - ETA: 0s - loss: 6.3559e-04 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 13s 104ms/step - loss: 6.3559e-04 - accuracy: 1.0000 - val_loss: 4.2014 - val_accuracy: 0.7853
# Epoch 47/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 00047: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 14s 110ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 4.3921 - val_accuracy: 0.7812
# Epoch 48/200
# 127/127 [==============================] - ETA: 0s - loss: 6.6197e-04 - accuracy: 0.9998
# Epoch 00048: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 14s 109ms/step - loss: 6.6197e-04 - accuracy: 0.9998 - val_loss: 4.2213 - val_accuracy: 0.7873
# Epoch 49/200
# 127/127 [==============================] - ETA: 0s - loss: 5.2072e-04 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 13s 105ms/step - loss: 5.2072e-04 - accuracy: 1.0000 - val_loss: 4.3465 - val_accuracy: 0.7823
# Epoch 50/200
# 127/127 [==============================] - ETA: 0s - loss: 8.0501e-04 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 14s 107ms/step - loss: 8.0501e-04 - accuracy: 1.0000 - val_loss: 4.2845 - val_accuracy: 0.7873
# Epoch 51/200
# 127/127 [==============================] - ETA: 0s - loss: 4.7946e-04 - accuracy: 1.0000
# Epoch 00051: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 14s 112ms/step - loss: 4.7946e-04 - accuracy: 1.0000 - val_loss: 4.3925 - val_accuracy: 0.7802
# Epoch 52/200
# 127/127 [==============================] - ETA: 0s - loss: 5.6178e-04 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.79133
# 127/127 [==============================] - 13s 106ms/step - loss: 5.6178e-04 - accuracy: 1.0000 - val_loss: 4.3784 - val_accuracy: 0.7812
# Epoch 00052: early stopping
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# max_pooling2d_15 (MaxPooling (None, 160, 120, 3)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 160, 120, 3)       228
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 160, 120, 16)      1216
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 80, 60, 16)        0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 80, 60, 16)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 80, 60, 32)        12832
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 80, 60, 32)        25632
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 40, 30, 32)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 40, 30, 32)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 38400)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               9830656
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 9,870,821
# Trainable params: 9,870,821
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,4))
 
plt.subplot(1,2,1)
plt.plot(history.history['loss'], 'b-', label = 'loss')
plt.plot(history.history['val_loss'], 'r--', label = 'val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], 'g-', label = 'acc')
plt.plot(history.history['val_accuracy'], 'k--', label = 'val_acc')
plt.xlabel('Epoch')
plt.ylim([0.7, 1])
plt.legend()

plt.show()

# %%
results = model.evaluate(valid_generator)
print('Test accuracy: ', results[1])
# Out:
# 40/40 [==============================] - 3s 80ms/step - loss: 3.6620 - accuracy: 0.7890
# Test accuracy:  0.7889763712882996

# %%
model.save('../models/audio_models/CNN.h5')
